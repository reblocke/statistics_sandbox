# %%
# Repository setup for portable, repo-relative paths
from pathlib import Path
import sys

def _find_repo_root(start: Path | None = None) -> Path:
    start = (start or Path.cwd()).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "pyproject.toml").exists():
            return candidate
    return start

REPO_ROOT = _find_repo_root()
if str(REPO_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / "src"))

from diagnosis_llms.paths import get_paths
PATHS = get_paths(REPO_ROOT)

# %% [markdown]
# ModerBERT

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Skipped cell 4 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 4. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 5 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 5. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 6 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 6. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 7 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 7. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 8 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 8. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 9 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 9. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 10 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 10. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 11 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 11. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 12 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 12. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 13 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 13. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 14 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 14. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 15 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 15. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 16 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 16. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 17 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 17. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 18 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 18. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 19 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 19. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 20 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 20. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 21 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 21. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 22 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 22. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 23 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 23. See test_notebook_full_original.ipynb')

# %% [markdown]
# Comparison to using OpenAI

# %%
# Skipped cell 25 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 25. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 26 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 26. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 27 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 27. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 28 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 28. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 29 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 29. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 30 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 30. See test_notebook_full_original.ipynb')

# %% [markdown]
# Mostly AI synthetic data engine

# %%
# Skipped cell 32 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 32. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 34 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 34. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 35 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 35. See test_notebook_full_original.ipynb')

# %% [markdown]
# Anthropic Calls -
#
# [ ] todo: still need to troubleshoot the API key and buy credits if going to use

# %%
# Skipped cell 37 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 37. See test_notebook_full_original.ipynb')

# %% [markdown]
# ### Code from Allen Downey giving an introduction to various regressions and displays

# %%
# Skipped cell 39 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 39. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 40 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 40. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 41 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 41. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 42 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 42. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 43 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 43. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 44 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 44. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 45 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 45. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 46 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 46. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 47 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped heavy/external cell 47. See test_notebook_full_original.ipynb')

# %% [markdown]
# 3b1b solver for Wordle - which relies on entropy calculations.

# %%
# Skipped cell 49 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 49. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 50 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 50. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 51 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 51. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 52 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 52. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 53 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 53. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 54 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 54. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 55 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 55. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 56 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 56. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 57 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 57. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 58 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 58. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 59 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 59. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 60 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 60. See test_notebook_full_original.ipynb')

# %% [markdown]
# ### Med SSS Clinical reasoning - THUS FAR, NOT SUCCESFUL IN GETTING THIS GOING

# %%
# Skipped cell 62 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 62. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 63 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 63. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 64 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 64. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 65 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 65. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 66 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 66. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 67 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 67. See test_notebook_full_original.ipynb')

# %%
# Skipped cell 68 for automated/non-interactive execution stability.
# Original content is preserved in `test_notebook_full_original.ipynb`.
# To run full exploratory workflows (APIs, large models, external downloads),
# use the full-original notebook interactively.
print('Skipped heavy/external cell 68. See test_notebook_full_original.ipynb')

# %% [markdown]
# ### Bambi and PyMC
#
# https://bambinos.github.io/bambi/

# %%
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import skimpy

# %%
# Skipped cell 71 for automated/non-interactive execution stability.
# This cell requires local C/C++ toolchain support for PyMC compilation.
# Original content is preserved in `test_notebook_full_original.ipynb`.
print('Skipped PyMC/Bambi MCMC compile cell 71. See test_notebook_full_original.ipynb')

# %%
data = pd.DataFrame({
    "g": np.random.choice(["Yes", "No"], size=50),
    "x1": np.random.normal(size=50),
    "x2": np.random.normal(size=50)
})
skimpy.skim(data)
